# %% [markdown]
# # 5 — Over-Sampling with SMOTE
#
# First of the four augmentation notebooks. Combines random under-sampling of
# Non-SEP with SMOTE interpolation of the SEP class, so both classes meet in the
# middle.
#
# **Input:** `final_split_data_HybridNorm_Tomek` (from notebook 3)
#
# **Output:** `results/<classifier>_tomek_{smote_balanced,rus8000_smote8000,rus2000_smote2000,rus500_smote500}.txt`
#
# **Run after:** notebook 3.
#
# ## Variants
#
# | variant | Non-SEP | SEP |
# |---|---|---|
# | `tomek_smote_balanced` | all | SMOTE up to match all Non-SEP |
# | `tomek_rus8000_smote8000` | 8000 | 8000 |
# | `tomek_rus2000_smote2000` | 2000 | 2000 |
# | `tomek_rus500_smote500` | 500 | 500 |
#
# SMOTE interpolates between real SEP samples in feature space. Compare against
# ADASYN (notebook 8), TimeGAN (6–7) and diffusion (9–10).
#
# **Augmentation is applied to the training set only.**

# %% [markdown]
# ## 1. Load Tomek Data and Apply RUS + SMOTE

# %%
import pickle
import numpy as np
import os
import time

from imblearn.over_sampling import SMOTE

def load_split(path):
    with open(path, "rb") as f:
        data = pickle.load(f)
    return data["X"].astype(np.float32), data["y"]


# ---------------------------------------------------------
# Load saved Tomek-cleaned dataset
# ---------------------------------------------------------
folder = "./final_split_data_HybridNorm_Tomek"

X_train, y_train = load_split(f"{folder}/train_set.pkl")
X_val,   y_val   = load_split(f"{folder}/val_set.pkl")
X_test,  y_test  = load_split(f"{folder}/test_set.pkl")

print("Loaded Tomek-cleaned dataset:")
print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape,   y_val.shape)
print("Test :", X_test.shape,  y_test.shape)


# ---------------------------------------------------------
# Prepare indices
# ---------------------------------------------------------
N, T, F = X_train.shape

nonsep_idx = np.where(y_train.astype(int) == 0)[0]
sep_idx    = np.where(y_train.astype(int) == 1)[0]

original_nonsep = len(nonsep_idx)
original_sep    = len(sep_idx)

X_real_sep_all = X_train[sep_idx].astype(np.float32)
X_nonsep_all   = X_train[nonsep_idx].astype(np.float32)

print("\nOriginal Tomek-cleaned training class counts:")
print("Non-SEP:", original_nonsep)
print("SEP    :", original_sep)
print(f"Ratio  : {original_nonsep / original_sep:.1f}x")
print("─" * 80)


# ---------------------------------------------------------
# Create synthetic SEP samples once using SMOTE
# Generate enough synthetic SEP for the largest target
# ---------------------------------------------------------
rng = np.random.default_rng(seed=42)

N_SYNTHETIC_SEP = max(12000, original_nonsep - original_sep)

print(f"\nSynthetic SEP samples to generate: {N_SYNTHETIC_SEP}")

X_train_flat = X_train.reshape(X_train.shape[0], T * F)

k_neighbors = min(3, original_sep - 1)

if k_neighbors < 1:
    raise ValueError(
        f"Not enough SEP samples for SMOTE. SEP count = {original_sep}"
    )

smote = SMOTE(
    sampling_strategy={1: original_sep + N_SYNTHETIC_SEP},
    k_neighbors=k_neighbors,
    random_state=42
)

# ---------------------------------------------------------
# Measure SMOTE synthetic generation time
# ---------------------------------------------------------
smote_start_time = time.time()

X_res_flat, y_res = smote.fit_resample(X_train_flat, y_train)

smote_infer_time = time.time() - smote_start_time

# SMOTE appends synthetic samples after the original samples
n_original = len(X_train_flat)

X_synthetic_flat = X_res_flat[n_original:]
y_synthetic      = y_res[n_original:]

X_synthetic_sep_all = X_synthetic_flat[y_synthetic.astype(int) == 1]
X_synthetic_sep_all = X_synthetic_sep_all.reshape(-1, T, F).astype(np.float32)

n_synthetic_generated = len(X_synthetic_sep_all)

print("\nCreated SMOTE synthetic SEP pool:")
print(f"Synthetic SEP shape          : {X_synthetic_sep_all.shape}")
print(f"Synthetic SEP count          : {n_synthetic_generated}")
print(f"SMOTE generation time        : {smote_infer_time:.4f}s")
print(f"SMOTE time per synthetic SEP : {smote_infer_time / n_synthetic_generated * 1000:.4f}ms")
print("─" * 80)


# ---------------------------------------------------------
# Save real vs synthetic SEP samples once
# ---------------------------------------------------------
SAVE_DIR = "./sep_samples"
os.makedirs(SAVE_DIR, exist_ok=True)

n_compare = min(118, len(X_real_sep_all), len(X_synthetic_sep_all))

idx_real_compare = rng.choice(
    len(X_real_sep_all),
    size=n_compare,
    replace=False
)

idx_synthetic_compare = rng.choice(
    len(X_synthetic_sep_all),
    size=n_compare,
    replace=False
)

save_path = os.path.join(SAVE_DIR, "sep_real_vs_synthetic_smote.pkl")

with open(save_path, "wb") as f:
    pickle.dump({
        "X_real_sep": X_real_sep_all[idx_real_compare],
        "y_real_sep": np.zeros(n_compare, dtype=np.int32),      # 0 = real

        "X_synthetic_sep": X_synthetic_sep_all[idx_synthetic_compare],
        "y_synthetic_sep": np.ones(n_compare, dtype=np.int32),  # 1 = synthetic

        "n_real_sep_total": original_sep,
        "n_synthetic_sep_total": len(X_synthetic_sep_all),
        "n_compare": n_compare,
        "k_neighbors": k_neighbors,
        "smote_infer_time": smote_infer_time,
        "smote_time_per_sample_ms": smote_infer_time / n_synthetic_generated * 1000,
    }, f)

print(f"Saved real vs synthetic SMOTE SEP samples → {os.path.abspath(save_path)}")
print(f"Real SEP      : {n_compare}")
print(f"Synthetic SEP : {n_compare}")
print("─" * 80)


# ---------------------------------------------------------
# Dataset configurations
# ---------------------------------------------------------
# tomek_smote_balanced:
#   No RUS. Keep all Non-SEP.
#   Use synthetic SEP to make total SEP = total Non-SEP.
#
# tomek_rus*_smote*:
#   RUS Non-SEP to target.
#   Use synthetic SEP to make total SEP = target.

smote_configs = {
    "tomek_smote_balanced": {
        "nonsep_target": original_nonsep,
        "sep_target": original_nonsep,
        "use_rus": False,
    },

    "tomek_rus8000_smote8000": {
        "nonsep_target": 8000,
        "sep_target": 8000,
        "use_rus": True,
    },

    "tomek_rus2000_smote2000": {
        "nonsep_target": 2000,
        "sep_target": 2000,
        "use_rus": True,
    },

    "tomek_rus500_smote500": {
        "nonsep_target": 500,
        "sep_target": 500,
        "use_rus": True,
    },
}


# ---------------------------------------------------------
# Create datasets in memory
# ---------------------------------------------------------
datasets_smote = {}

print("\nCreating Tomek + SMOTE datasets:")
print(
    f"{'Dataset':<28} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Real SEP':>10} "
    f"{'Synthetic SEP':>14} "
    f"{'RUS?':>8} "
    f"{'Shape'}"
)
print("─" * 105)

for dataset_name, cfg in smote_configs.items():

    nonsep_target = cfg["nonsep_target"]
    sep_target = cfg["sep_target"]
    use_rus = cfg["use_rus"]

    if nonsep_target > original_nonsep:
        raise ValueError(
            f"{dataset_name}: requested {nonsep_target} Non-SEP samples, "
            f"but only {original_nonsep} are available after Tomek."
        )

    if sep_target < original_sep:
        raise ValueError(
            f"{dataset_name}: requested {sep_target} SEP samples, "
            f"but original SEP count is {original_sep}. "
            f"This code keeps all real SEP samples."
        )

    n_synthetic_needed = sep_target - original_sep

    if n_synthetic_needed > len(X_synthetic_sep_all):
        raise ValueError(
            f"{dataset_name}: requested {n_synthetic_needed} synthetic SEP samples, "
            f"but only {len(X_synthetic_sep_all)} are available."
        )

    # -----------------------------------------------------
    # Select Non-SEP samples
    # -----------------------------------------------------
    if use_rus:
        selected_nonsep_idx = rng.choice(
            len(X_nonsep_all),
            size=nonsep_target,
            replace=False
        )

        X_nonsep = X_nonsep_all[selected_nonsep_idx]

    else:
        X_nonsep = X_nonsep_all.copy()

    y_nonsep = np.zeros(len(X_nonsep), dtype=np.float32)

    # -----------------------------------------------------
    # Select synthetic SEP from the fixed SMOTE pool
    # -----------------------------------------------------
    selected_syn_idx = rng.choice(
        len(X_synthetic_sep_all),
        size=n_synthetic_needed,
        replace=False
    )

    X_syn_sep = X_synthetic_sep_all[selected_syn_idx]

    # Keep all real SEP + selected synthetic SEP
    X_sep = np.concatenate([X_real_sep_all, X_syn_sep], axis=0).astype(np.float32)
    y_sep = np.ones(len(X_sep), dtype=np.float32)

    # -----------------------------------------------------
    # Combine and shuffle
    # -----------------------------------------------------
    X_res = np.concatenate([X_nonsep, X_sep], axis=0).astype(np.float32)
    y_res = np.concatenate([y_nonsep, y_sep], axis=0)

    final_perm = rng.permutation(len(y_res))
    X_res = X_res[final_perm]
    y_res = y_res[final_perm]

    datasets_smote[dataset_name] = {
        "X_train": X_res,
        "y_train": y_res,

        "X_val": X_val,
        "y_val": y_val,

        "X_test": X_test,
        "y_test": y_test,

        "nonsep_target": nonsep_target,
        "sep_target": sep_target,
        "use_rus": use_rus,
        "real_sep": original_sep,
        "synthetic_sep": n_synthetic_needed,
        "smote_infer_time": smote_infer_time,
        "smote_time_per_sample_ms": smote_infer_time / n_synthetic_generated * 1000,
    }

    final_counts = np.bincount(y_res.astype(int), minlength=2)

    print(
        f"{dataset_name:<28} "
        f"{final_counts[0]:>8} "
        f"{final_counts[1]:>8} "
        f"{original_sep:>10} "
        f"{n_synthetic_needed:>14} "
        f"{str(use_rus):>8} "
        f"{X_res.shape}"
    )


print("\n✅ Tomek + SMOTE datasets are ready in memory.")
print("Dictionary name: datasets_smote")
print("Datasets:")
for key in datasets_smote.keys():
    print(" ", key)

print(f"\n✅ Real vs synthetic SMOTE SEP samples saved to: {os.path.abspath(SAVE_DIR)}/")
print(f"SMOTE inference/generation time       : {smote_infer_time:.4f}s")
print(f"SMOTE time per synthetic SEP sample   : {smote_infer_time / n_synthetic_generated * 1000:.4f}ms")
# Out:
# Loaded Tomek-cleaned dataset:
# Train: (12441, 288, 10) (12441,)
# Val  : (1780, 288, 10) (1780,)
# Test : (3559, 288, 10) (3559,)
#
# Original Tomek-cleaned training class counts:
# Non-SEP: 12323
# SEP    : 118
# Ratio  : 104.4x
# ────────────────────────────────────────────────────────────────────────────────
#
# Synthetic SEP samples to generate: 12205
#
# Created SMOTE synthetic SEP pool:
# Synthetic SEP shape          : (12205, 288, 10)
# Synthetic SEP count          : 12205
# SMOTE generation time        : 0.4505s
# SMOTE time per synthetic SEP : 0.0369ms
# ────────────────────────────────────────────────────────────────────────────────
# Saved real vs synthetic SMOTE SEP samples → /Users/samskanderi/Documents/Claude/SEP_DataAugmentation/sep_samples/sep_real_vs_synthetic_smote.pkl
# Real SEP      : 118
# Synthetic SEP : 118
# ────────────────────────────────────────────────────────────────────────────────
#
# Creating Tomek + SMOTE datasets:
# Dataset                       Non-SEP      SEP   Real SEP  Synthetic SEP     RUS? Shape
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# tomek_smote_balanced            12323    12323        118          12205    False (24646, 288, 10)
# tomek_rus8000_smote8000          8000     8000        118           7882     True (16000, 288, 10)
# tomek_rus2000_smote2000          2000     2000        118           1882     True (4000, 288, 10)
# tomek_rus500_smote500             500      500        118            382     True (1000, 288, 10)
#
# ✅ Tomek + SMOTE datasets are ready in memory.
# Dictionary name: datasets_smote
# Datasets:
#   tomek_smote_balanced
#   tomek_rus8000_smote8000
#   tomek_rus2000_smote2000
#   tomek_rus500_smote500
#
# ✅ Real vs synthetic SMOTE SEP samples saved to: /Users/samskanderi/Documents/Claude/SEP_DataAugmentation/sep_samples/
# SMOTE inference/generation time       : 0.4505s
# SMOTE time per synthetic SEP sample   : 0.0369ms

# %% [markdown]
# ## 2. Catch22 Feature Extraction (SVM Input)

# %%
import numpy as np
from joblib import Parallel, delayed
from sktime.transformations.panel.catch22 import Catch22
from sklearn.impute import SimpleImputer
import warnings

# ══════════════════════════════════════════════════════════════
# CATCH22 FEATURE EXTRACTION FOR TOMEK + SMOTE DATASETS
# Input : datasets_smote
#         tomek_smote_balanced,
#         tomek_rus8000_smote8000,
#         tomek_rus2000_smote2000,
#         tomek_rus500_smote500
# Output: datasets_svm_smote
# ══════════════════════════════════════════════════════════════

def _catch22_chunk(X_chunk):
    transformer = Catch22(catch24=False)
    return transformer.fit_transform(X_chunk).to_numpy()


def extract_catch22(X, label="", n_jobs=-1, chunk_size=200):

    n_samples, n_timepoints, n_channels = X.shape

    # Replace NaN / Inf before Catch22
    if not np.isfinite(X).all():
        n_bad = (~np.isfinite(X)).sum()
        print(f"    ⚠️ {n_bad} non-finite values in {label} — replacing with channel median")

        X = X.copy()

        for c in range(n_channels):
            col = X[:, :, c]
            median_c = np.nanmedian(col)

            if not np.isfinite(median_c):
                median_c = 0.0

            col[~np.isfinite(col)] = median_c
            X[:, :, c] = col

    # sktime expects shape: (samples, channels, timesteps)
    X_sktime = X.transpose(0, 2, 1).astype(np.float64)

    chunks = [
        X_sktime[i:i + chunk_size]
        for i in range(0, n_samples, chunk_size)
    ]

    print(f"    {label}: {n_samples} samples in {len(chunks)} chunks", flush=True)

    results = Parallel(n_jobs=n_jobs)(
        delayed(_catch22_chunk)(chunk)
        for chunk in chunks
    )

    X_feat = np.vstack(results)

    expected_cols = 22 * n_channels

    assert X_feat.shape == (n_samples, expected_cols), (
        f"Unexpected shape for {label}: {X_feat.shape}, "
        f"expected ({n_samples}, {expected_cols})"
    )

    return X_feat.astype(np.float32)


# ══════════════════════════════════════════════════════════════
# Sanity check before extraction
# ══════════════════════════════════════════════════════════════

print("Pre-extraction value range check:")
print(
    f"{'Dataset':<26} "
    f"{'Train shape':<22} "
    f"{'Finite?':<10} "
    f"{'Min':>12} "
    f"{'Max':>12} "
    f"{'NaN/Inf':>10} "
    f"{'Class 0':>8} "
    f"{'Class 1':>8} "
    f"{'Ratio':>8}"
)
print("─" * 130)

for dataset_name, d in datasets_smote.items():
    X = d["X_train"]
    y = d["y_train"]

    counts = np.bincount(y.astype(int), minlength=2)
    ratio = counts[0] / counts[1] if counts[1] > 0 else np.inf

    print(
        f"{dataset_name:<26} "
        f"{str(X.shape):<22} "
        f"{str(np.isfinite(X).all()):<10} "
        f"{np.nanmin(X):>12.4f} "
        f"{np.nanmax(X):>12.4f} "
        f"{(~np.isfinite(X)).sum():>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>7.1f}x"
    )


# ══════════════════════════════════════════════════════════════
# Extract Catch22 features
# ══════════════════════════════════════════════════════════════

datasets_svm_smote = {}

print("\nExtracting Catch22 features for Tomek + SMOTE datasets...")

for dataset_name, d in datasets_smote.items():

    print(f"\n[{dataset_name}] extracting train...")
    X_tr = extract_catch22(
        d["X_train"],
        label=f"{dataset_name}/train",
        n_jobs=-1,
        chunk_size=200
    )

    print(f"[{dataset_name}] extracting val...")
    X_va = extract_catch22(
        d["X_val"],
        label=f"{dataset_name}/val",
        n_jobs=-1,
        chunk_size=200
    )

    print(f"[{dataset_name}] extracting test...")
    X_te = extract_catch22(
        d["X_test"],
        label=f"{dataset_name}/test",
        n_jobs=-1,
        chunk_size=200
    )

    datasets_svm_smote[dataset_name] = {
        "X_train": X_tr,
        "y_train": d["y_train"],

        "X_val": X_va,
        "y_val": d["y_val"],

        "X_test": X_te,
        "y_test": d["y_test"],

        "nonsep_target": d.get("nonsep_target", None),
        "sep_target": d.get("sep_target", None),
        "use_rus": d.get("use_rus", None),
    }

    print(
        f"[{dataset_name}] ✓ "
        f"train {X_tr.shape} | "
        f"val {X_va.shape} | "
        f"test {X_te.shape}"
    )


# ══════════════════════════════════════════════════════════════
# Impute Catch22 features
# Fit imputer on train only, apply to val/test
# ══════════════════════════════════════════════════════════════

print("\nChecking and imputing Catch22 features...")

for dataset_name in list(datasets_svm_smote.keys()):

    d = datasets_svm_smote[dataset_name]

    X_tr = d["X_train"].copy()
    X_va = d["X_val"].copy()
    X_te = d["X_test"].copy()

    y_tr = d["y_train"]
    y_va = d["y_val"]
    y_te = d["y_test"]

    n_bad_tr = (~np.isfinite(X_tr)).sum()
    n_bad_va = (~np.isfinite(X_va)).sum()
    n_bad_te = (~np.isfinite(X_te)).sum()

    if n_bad_tr > 0 or n_bad_va > 0 or n_bad_te > 0:

        print(
            f"  ⚠️ [{dataset_name}] non-finite values — "
            f"train: {n_bad_tr}, val: {n_bad_va}, test: {n_bad_te} → imputing"
        )

        X_tr = np.where(np.isfinite(X_tr), X_tr, np.nan)
        X_va = np.where(np.isfinite(X_va), X_va, np.nan)
        X_te = np.where(np.isfinite(X_te), X_te, np.nan)

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")

            imputer = SimpleImputer(strategy="median")

            X_tr = imputer.fit_transform(X_tr)
            X_va = imputer.transform(X_va)
            X_te = imputer.transform(X_te)

        X_tr = np.nan_to_num(X_tr, nan=0.0, posinf=0.0, neginf=0.0)
        X_va = np.nan_to_num(X_va, nan=0.0, posinf=0.0, neginf=0.0)
        X_te = np.nan_to_num(X_te, nan=0.0, posinf=0.0, neginf=0.0)

        print(f"  ✓ [{dataset_name}] imputed")

    else:
        print(f"  ✓ [{dataset_name}] no NaN or Inf")

    datasets_svm_smote[dataset_name] = {
        "X_train": X_tr.astype(np.float32),
        "y_train": y_tr,

        "X_val": X_va.astype(np.float32),
        "y_val": y_va,

        "X_test": X_te.astype(np.float32),
        "y_test": y_te,

        "nonsep_target": d.get("nonsep_target", None),
        "sep_target": d.get("sep_target", None),
        "use_rus": d.get("use_rus", None),
    }


# ══════════════════════════════════════════════════════════════
# Final summary
# ══════════════════════════════════════════════════════════════

print("\n✅ SVM-ready Catch22 Tomek + SMOTE datasets are ready:")
print(list(datasets_svm_smote.keys()))

print(
    f"\n{'Dataset':<26} "
    f"{'Train shape':<18} "
    f"{'Val shape':<18} "
    f"{'Test shape':<18} "
    f"{'Class 0':>8} "
    f"{'Class 1':>8} "
    f"{'Ratio':>8}"
)
print("─" * 115)

for name, d in datasets_svm_smote.items():
    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1] if counts[1] > 0 else np.inf

    print(
        f"{name:<26} "
        f"{str(d['X_train'].shape):<18} "
        f"{str(d['X_val'].shape):<18} "
        f"{str(d['X_test'].shape):<18} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>7.1f}x"
    )
# Out:
# Pre-extraction value range check:
# Dataset                    Train shape            Finite?             Min          Max    NaN/Inf  Class 0  Class 1    Ratio
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# tomek_smote_balanced       (24646, 288, 10)       True            -6.5136      18.1921          0    12323    12323     1.0x
# tomek_rus8000_smote8000    (16000, 288, 10)       True            -6.5136      18.1921          0     8000     8000     1.0x
# tomek_rus2000_smote2000    (4000, 288, 10)        True            -6.5136      17.8322          0     2000     2000     1.0x
# tomek_rus500_smote500      (1000, 288, 10)        True            -6.5136      17.8322          0      500      500     1.0x
#
# Extracting Catch22 features for Tomek + SMOTE datasets...
#
# [tomek_smote_balanced] extracting train...
#     tomek_smote_balanced/train: 24646 samples in 124 chunks
# [tomek_smote_balanced] extracting val...
#     tomek_smote_balanced/val: 1780 samples in 9 chunks
# [tomek_smote_balanced] extracting test...
#     tomek_smote_balanced/test: 3559 samples in 18 chunks
# [tomek_smote_balanced] ✓ train (24646, 220) | val (1780, 220) | test (3559, 220)
#
# [tomek_rus8000_smote8000] extracting train...
#     tomek_rus8000_smote8000/train: 16000 samples in 80 chunks
# [tomek_rus8000_smote8000] extracting val...
#     tomek_rus8000_smote8000/val: 1780 samples in 9 chunks
# [tomek_rus8000_smote8000] extracting test...
#     tomek_rus8000_smote8000/test: 3559 samples in 18 chunks
# [tomek_rus8000_smote8000] ✓ train (16000, 220) | val (1780, 220) | test (3559, 220)
#
# [tomek_rus2000_smote2000] extracting train...
#     tomek_rus2000_smote2000/train: 4000 samples in 20 chunks
# [tomek_rus2000_smote2000] extracting val...
#     tomek_rus2000_smote2000/val: 1780 samples in 9 chunks
# [tomek_rus2000_smote2000] extracting test...
#     tomek_rus2000_smote2000/test: 3559 samples in 18 chunks
# [tomek_rus2000_smote2000] ✓ train (4000, 220) | val (1780, 220) | test (3559, 220)
#
# [tomek_rus500_smote500] extracting train...
#     tomek_rus500_smote500/train: 1000 samples in 5 chunks
# [tomek_rus500_smote500] extracting val...
#     tomek_rus500_smote500/val: 1780 samples in 9 chunks
# [tomek_rus500_smote500] extracting test...
#     tomek_rus500_smote500/test: 3559 samples in 18 chunks
# [tomek_rus500_smote500] ✓ train (1000, 220) | val (1780, 220) | test (3559, 220)
#
# Checking and imputing Catch22 features...
#   ⚠️ [tomek_smote_balanced] non-finite values — train: 190724, val: 20276, test: 33898 → imputing
#   ✓ [tomek_smote_balanced] imputed
#   ⚠️ [tomek_rus8000_smote8000] non-finite values — train: 123865, val: 20276, test: 33898 → imputing
#   ✓ [tomek_rus8000_smote8000] imputed
#   ⚠️ [tomek_rus2000_smote2000] non-finite values — train: 30894, val: 20276, test: 33898 → imputing
#   ✓ [tomek_rus2000_smote2000] imputed
#   ⚠️ [tomek_rus500_smote500] non-finite values — train: 7561, val: 20276, test: 33898 → imputing
#   ✓ [tomek_rus500_smote500] imputed
#
# ✅ SVM-ready Catch22 Tomek + SMOTE datasets are ready:
# ['tomek_smote_balanced', 'tomek_rus8000_smote8000', 'tomek_rus2000_smote2000', 'tomek_rus500_smote500']
#
# Dataset                    Train shape        Val shape          Test shape          Class 0  Class 1    Ratio
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# tomek_smote_balanced       (24646, 220)       (1780, 220)        (3559, 220)           12323    12323     1.0x
# tomek_rus8000_smote8000    (16000, 220)       (1780, 220)        (3559, 220)            8000     8000     1.0x
# tomek_rus2000_smote2000    (4000, 220)        (1780, 220)        (3559, 220)            2000     2000     1.0x
# tomek_rus500_smote500      (1000, 220)        (1780, 220)        (3559, 220)             500      500     1.0x

# %% [markdown]
# ## 3. Classification

# %%
# ══════════════════════════════════════════════════════════════
# HELPER FUNCTIONS
# ══════════════════════════════════════════════════════════════
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
import time
import os

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)


def compute_metrics(y_true, y_pred):
    cm             = confusion_matrix(y_true, y_pred)
    TN, FP, FN, TP = cm.ravel()

    recall    = TP / (TP + FN) if (TP + FN) > 0 else 0.0
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0.0
    f1        = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
    accuracy  = (TP + TN) / (TP + TN + FP + FN)

    tss  = recall - FP / (FP + TN) if (FP + TN) > 0 else 0.0

    # HSS1 (Barnes & Leka 2008): (TP + TN - N) / P  ==  (TP - FP) / (TP + FN)
    hss1 = (TP - FP) / (TP + FN) if (TP + FN) > 0 else 0.0

    denom = ((TP + FN) * (FN + TN) + (TP + FP) * (FP + TN))
    hss2  = 2 * (TP * TN - FP * FN) / denom if denom > 0 else 0.0

    hits_random = (TP + FP) * (TP + FN) / (TP + TN + FP + FN)
    gss = (TP - hits_random) / (TP + FP + FN - hits_random) if (TP + FP + FN - hits_random) > 0 else 0.0

    # False Alarm Ratio: of the alarms issued, the fraction that were wrong.
    # nan when no alarm is issued at all -- 0.0 there would read as flawless.
    far = FP / (TP + FP) if (TP + FP) > 0 else float('nan')

    # Frequency bias: alarms issued per event that actually occurred.
    # 1.0 = calibrated, > 1 over-forecasting, < 1 under-forecasting.
    bias = (TP + FP) / (TP + FN) if (TP + FN) > 0 else 0.0

    return {
        'TP': int(TP), 'TN': int(TN), 'FP': int(FP), 'FN': int(FN),
        'tss': tss, 'far': far, 'bias': bias,
        'hss1': hss1, 'hss2': hss2, 'gss': gss,
        'recall': recall, 'precision': precision, 'f1': f1, 'accuracy': accuracy
    }


def train_and_evaluate(model, X_train, y_train, X_test, y_test):
    t0         = time.time()
    model.fit(X_train, y_train)
    train_time = time.time() - t0

    t0         = time.time()
    y_pred     = model.predict(X_test)
    infer_time = time.time() - t0

    metrics = compute_metrics(y_test, y_pred)
    metrics['train_time'] = train_time
    metrics['infer_time'] = infer_time
    return metrics


def save_results(metrics_list, filepath):
    with open(filepath, 'w') as f:
        for m in metrics_list:
            line = (f"{m['TP']},{m['TN']},{m['FP']},{m['FN']},"
                    f"{m['tss']:.6f},{m['hss1']:.6f},{m['hss2']:.6f},{m['gss']:.6f},"
                    f"{m['recall']:.6f},{m['f1']:.6f},{m['accuracy']:.6f},"
                    f"{m['train_time']:.4f},{m['infer_time']:.4f},"
                    f"{m['far']:.6f},{m['bias']:.6f}")
            f.write(line + "\n")


def print_results(metrics_list, title):
    keys = ['tss', 'far', 'bias', 'hss1', 'hss2', 'gss',
            'recall', 'precision', 'f1', 'accuracy', 'train_time', 'infer_time']
    print(f"\n{'─'*55}")
    print(f"  {title}")
    print(f"{'─'*55}")
    for i, m in enumerate(metrics_list):
        print(f"  Run {i+1}: TP={m['TP']}  TN={m['TN']}  FP={m['FP']}  FN={m['FN']}")
        print(f"         TSS={m['tss']:.4f}  FAR={m['far']:.4f}  Bias={m['bias']:.2f}")
        print(f"         HSS1={m['hss1']:.4f}  HSS2={m['hss2']:.4f}  GSS={m['gss']:.4f}")
        print(f"         Recall={m['recall']:.4f}  Precision={m['precision']:.4f}  F1={m['f1']:.4f}  Acc={m['accuracy']:.4f}")
        print(f"         Train={m['train_time']:.2f}s  Infer={m['infer_time']:.4f}s")
        print()
    print(f"  ── Average of {len(metrics_list)} runs ──")
    for k in keys:
        avg = np.nanmean([m[k] for m in metrics_list])
        print(f"  {k:<12} : {avg:.4f}")
    print(f"{'─'*55}")

# %% [markdown]
# ### SVM

# %%
import os
import copy
import warnings
import numpy as np

from sklearn.svm import SVC
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# ══════════════════════════════════════════════════════════════
# SVM FINAL EXPERIMENTS — TOMEK + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best model: RBF-SVC, C=0.1, gamma=scale, class_weight=balanced
#
# Input datasets:
# datasets_svm_smote
#   tomek_smote_balanced
#   tomek_rus8000_smote8000
#   tomek_rus2000_smote2000
#   tomek_rus500_smote500
# ══════════════════════════════════════════════════════════════

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best SVM hyperparameters
# ---------------------------------------------------------
best_model_class = SVC

best_params = {
    "kernel": "rbf",
    "C": 0.1,
    "gamma": "scale",
    "class_weight": "balanced",
    "cache_size": 2000
}

TARGET_VARIANTS = [
    "tomek_smote_balanced",
    "tomek_rus8000_smote8000",
    "tomek_rus2000_smote2000",
    "tomek_rus500_smote500",
]

print("═" * 70)
print("Final SVM experiments on Tomek + SMOTE datasets")
print("Using fixed best hyperparameters")
print("═" * 70)
print(f"Model  : {best_model_class.__name__}")
print(f"Params : {best_params}")


# ---------------------------------------------------------
# Run final experiments on Tomek + SMOTE datasets
# ---------------------------------------------------------
all_smote_svm_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_svm_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_svm_smote[dataset_key]

    print("\n" + "─" * 70)
    print(f"Dataset : {dataset_key}")
    print(f"Model   : {best_model_class.__name__}")
    print(f"Params  : {best_params}")

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    train_ratio = train_counts[0] / train_counts[1] if train_counts[1] > 0 else np.inf

    print(f"Train shape : {d['X_train'].shape}")
    print(f"Val shape   : {d['X_val'].shape}")
    print(f"Test shape  : {d['X_test'].shape}")
    print(f"Train class : Non-SEP={train_counts[0]} | SEP={train_counts[1]} | Ratio={train_ratio:.1f}:1")
    print(f"Val class   : Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test class  : Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        model = best_model_class(**copy.deepcopy(best_params))

        metrics = train_and_evaluate(
            model,
            d["X_train"], d["y_train"],
            d["X_test"],  d["y_test"]
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.2f}s"
        )

    all_smote_svm_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"svm_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"SVM | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("SVM Tomek + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)
print("─" * 95)

for dataset_key, metrics_list in all_smote_svm_results.items():

    d = datasets_svm_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1] if counts[1] > 0 else np.inf

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest SVM Tomek + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Model   : {best_model_class.__name__}")
print(f"  Params  : {best_params}")

print("\nAll SVM Tomek + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
# Final SVM experiments on Tomek + SMOTE datasets
# Using fixed best hyperparameters
# ══════════════════════════════════════════════════════════════════════
# Model  : SVC
# Params : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : tomek_smote_balanced
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (24646, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=12323 | SEP=12323 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.2951 | F1=0.0352 | Recall=0.6176 | Precision=0.0181 | Train=38.59s
# Run 2: TSS=0.2951 | F1=0.0352 | Recall=0.6176 | Precision=0.0181 | Train=38.71s
#
# ───────────────────────────────────────────────────────
#   SVM | tomek_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=21  TN=2388  FP=1137  FN=13
#          TSS=0.2951  FAR=0.9819  Bias=34.06
#          HSS1=-32.8235  HSS2=0.0170  GSS=0.0086
#          Recall=0.6176  Precision=0.0181  F1=0.0352  Acc=0.6769
#          Train=38.59s  Infer=5.2315s
#
#   Run 2: TP=21  TN=2388  FP=1137  FN=13
#          TSS=0.2951  FAR=0.9819  Bias=34.06
#          HSS1=-32.8235  HSS2=0.0170  GSS=0.0086
#          Recall=0.6176  Precision=0.0181  F1=0.0352  Acc=0.6769
#          Train=38.71s  Infer=5.1927s
#
#   ── Average of 2 runs ──
#   tss          : 0.2951
#   far          : 0.9819
#   bias         : 34.0588
#   hss1         : -32.8235
#   hss2         : 0.0170
#   gss          : 0.0086
#   recall       : 0.6176
#   precision    : 0.0181
#   f1           : 0.0352
#   accuracy     : 0.6769
#   train_time   : 38.6522
#   infer_time   : 5.2121
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : tomek_rus8000_smote8000
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (16000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=8000 | SEP=8000 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.3356 | F1=0.0381 | Recall=0.6471 | Precision=0.0196 | Train=14.45s
# Run 2: TSS=0.3356 | F1=0.0381 | Recall=0.6471 | Precision=0.0196 | Train=14.27s
#
# ───────────────────────────────────────────────────────
#   SVM | tomek_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=22  TN=2427  FP=1098  FN=12
#          TSS=0.3356  FAR=0.9804  Bias=32.94
#          HSS1=-31.6471  HSS2=0.0200  GSS=0.0101
#          Recall=0.6471  Precision=0.0196  F1=0.0381  Acc=0.6881
#          Train=14.45s  Infer=3.5682s
#
#   Run 2: TP=22  TN=2427  FP=1098  FN=12
#          TSS=0.3356  FAR=0.9804  Bias=32.94
#          HSS1=-31.6471  HSS2=0.0200  GSS=0.0101
#          Recall=0.6471  Precision=0.0196  F1=0.0381  Acc=0.6881
#          Train=14.27s  Infer=3.5752s
#
#   ── Average of 2 runs ──
#   tss          : 0.3356
#   far          : 0.9804
#   bias         : 32.9412
#   hss1         : -31.6471
#   hss2         : 0.0200
#   gss          : 0.0101
#   recall       : 0.6471
#   precision    : 0.0196
#   f1           : 0.0381
#   accuracy     : 0.6881
#   train_time   : 14.3598
#   infer_time   : 3.5717
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : tomek_rus2000_smote2000
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (4000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=2000 | SEP=2000 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.3954 | F1=0.0604 | Recall=0.5588 | Precision=0.0319 | Train=0.86s
# Run 2: TSS=0.3954 | F1=0.0604 | Recall=0.5588 | Precision=0.0319 | Train=0.85s
#
# ───────────────────────────────────────────────────────
#   SVM | tomek_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=19  TN=2949  FP=576  FN=15
#          TSS=0.3954  FAR=0.9681  Bias=17.50
#          HSS1=-16.3824  HSS2=0.0431  GSS=0.0220
#          Recall=0.5588  Precision=0.0319  F1=0.0604  Acc=0.8339
#          Train=0.86s  Infer=1.0491s
#
#   Run 2: TP=19  TN=2949  FP=576  FN=15
#          TSS=0.3954  FAR=0.9681  Bias=17.50
#          HSS1=-16.3824  HSS2=0.0431  GSS=0.0220
#          Recall=0.5588  Precision=0.0319  F1=0.0604  Acc=0.8339
#          Train=0.85s  Infer=1.0535s
#
#   ── Average of 2 runs ──
#   tss          : 0.3954
#   far          : 0.9681
#   bias         : 17.5000
#   hss1         : -16.3824
#   hss2         : 0.0431
#   gss          : 0.0220
#   recall       : 0.5588
#   precision    : 0.0319
#   f1           : 0.0604
#   accuracy     : 0.8339
#   train_time   : 0.8539
#   infer_time   : 1.0513
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset : tomek_rus500_smote500
# Model   : SVC
# Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
# Train shape : (1000, 220)
# Val shape   : (1780, 220)
# Test shape  : (3559, 220)
# Train class : Non-SEP=500 | SEP=500 | Ratio=1.0:1
# Val class   : Non-SEP=1763 | SEP=17
# Test class  : Non-SEP=3525 | SEP=34
# ──────────────────────────────────────────────────────────────────────
# Run 1: TSS=0.4013 | F1=0.0852 | Recall=0.5000 | Precision=0.0466 | Train=0.07s
# Run 2: TSS=0.4013 | F1=0.0852 | Recall=0.5000 | Precision=0.0466 | Train=0.06s
#
# ───────────────────────────────────────────────────────
#   SVM | tomek_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=17  TN=3177  FP=348  FN=17
#          TSS=0.4013  FAR=0.9534  Bias=10.74
#          HSS1=-9.7353  HSS2=0.0689  GSS=0.0357
#          Recall=0.5000  Precision=0.0466  F1=0.0852  Acc=0.8974
#          Train=0.07s  Infer=0.3322s
#
#   Run 2: TP=17  TN=3177  FP=348  FN=17
#          TSS=0.4013  FAR=0.9534  Bias=10.74
#          HSS1=-9.7353  HSS2=0.0689  GSS=0.0357
#          Recall=0.5000  Precision=0.0466  F1=0.0852  Acc=0.8974
#          Train=0.06s  Infer=0.3344s
#
#   ── Average of 2 runs ──
#   tss          : 0.4013
#   far          : 0.9534
#   bias         : 10.7353
#   hss1         : -9.7353
#   hss2         : 0.0689
#   gss          : 0.0357
#   recall       : 0.5000
#   precision    : 0.0466
#   f1           : 0.0852
#   accuracy     : 0.8974
#   train_time   : 0.0651
#   infer_time   : 0.3333
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# SVM Tomek + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                     Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ───────────────────────────────────────────────────────────────────────────────────────────────
# tomek_smote_balanced          12323    12323       1.0x     0.2951     0.0352       0.6176
# tomek_rus8000_smote8000        8000     8000       1.0x     0.3356     0.0381       0.6471
# tomek_rus2000_smote2000        2000     2000       1.0x     0.3954     0.0604       0.5588
# tomek_rus500_smote500           500      500       1.0x     0.4013     0.0852       0.5000
#
# Best SVM Tomek + SMOTE dataset:
#   Dataset : tomek_rus500_smote500
#   Avg TSS : 0.4013
#   Model   : SVC
#   Params  : {'kernel': 'rbf', 'C': 0.1, 'gamma': 'scale', 'class_weight': 'balanced', 'cache_size': 2000}
#
# All SVM Tomek + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/Documents/Claude/SEP_DataAugmentation/results/
# Files: ['gru_hybrid.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_nonorm.txt', 'gru_tomek_nonsep_2000.txt', 'gru_tomek_nonsep_500.txt', 'gru_tomek_nonsep_8000.txt', 'gru_zscore_all.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_nonorm.txt', 'inceptiontime_tomek_nonsep_2000.txt', 'inceptiontime_tomek_nonsep_500.txt', 'inceptiontime_tomek_nonsep_8000.txt', 'inceptiontime_zscore_all.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_nonorm.txt', 'patchtst_tomek_nonsep_2000.txt', 'patchtst_tomek_nonsep_500.txt', 'patchtst_tomek_nonsep_8000.txt', 'patchtst_zscore_all.txt', 'svm_hybrid.txt', 'svm_hybrid_enn.txt', 'svm_hybrid_nearmiss.txt', 'svm_hybrid_tomek.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_nonorm.txt', 'svm_tomek_nonsep_2000.txt', 'svm_tomek_nonsep_500.txt', 'svm_tomek_nonsep_8000.txt', 'svm_tomek_rus2000_smote2000.txt', 'svm_tomek_rus500_smote500.txt', 'svm_tomek_rus8000_smote8000.txt', 'svm_tomek_smote_balanced.txt', 'svm_zscore_all.txt']

# %% [markdown]
# ### GRU

# %%
# ══════════════════════════════════════════════════════════════
# HELPER FUNCTIONS — PyTorch
# ══════════════════════════════════════════════════════════════
import torch
import torch.nn as nn
import numpy as np
import time
import os
import warnings
warnings.filterwarnings('ignore')

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")


class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size=128, num_layers=1, dropout=0.3):
        super(GRUModel, self).__init__()
        self.gru      = nn.GRU(input_size, hidden_size, num_layers=num_layers,
                               batch_first=True,
                               dropout=dropout if num_layers > 1 else 0)
        self.bn       = nn.BatchNorm1d(hidden_size)
        self.dropout  = nn.Dropout(dropout)
        self.fc1      = nn.Linear(hidden_size, 32)
        self.relu     = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)
        self.fc2      = nn.Linear(32, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out    = out[:, -1, :]
        out    = self.bn(out)
        out    = self.dropout(out)
        out    = self.relu(self.fc1(out))
        out    = self.dropout2(out)
        return self.fc2(out).squeeze()


def train_and_evaluate_gru(params, X_train, y_train, X_val, y_val, X_test, y_test, class_ratio=13):
    X_tr = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tr = torch.tensor(y_train, dtype=torch.float32).to(device)
    X_va = torch.tensor(X_val,   dtype=torch.float32).to(device)
    y_va = torch.tensor(y_val,   dtype=torch.float32).to(device)
    X_te = torch.tensor(X_test,  dtype=torch.float32).to(device)

    input_size = X_train.shape[2]
    model      = GRUModel(input_size,
                          hidden_size = params["units"],
                          num_layers  = params["layers"],
                          dropout     = params["dropout"]).to(device)

    pos_weight = torch.tensor([float(class_ratio)], dtype=torch.float32).to(device)
    criterion  = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer  = torch.optim.Adam(model.parameters(), lr=params["lr"])

    batch_size     = params["batch_size"]
    n_samples      = X_tr.shape[0]
    best_val_loss  = float('inf')
    patience_count = 0
    best_state     = None

    t0 = time.time()
    for epoch in range(50):
        model.train()
        perm = torch.randperm(n_samples)
        for i in range(0, n_samples, batch_size):
            idx    = perm[i:i + batch_size]
            xb, yb = X_tr[idx], y_tr[idx]
            optimizer.zero_grad()
            loss   = criterion(model(xb), yb)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = criterion(model(X_va), y_va).item()

        if val_loss < best_val_loss:
            best_val_loss  = val_loss
            patience_count = 0
            best_state     = {k: v.clone() for k, v in model.state_dict().items()}
        else:
            patience_count += 1
            if patience_count >= 5:
                break

    train_time = time.time() - t0

    model.load_state_dict(best_state)
    model.eval()
    t0 = time.time()
    with torch.no_grad():
        y_prob = torch.sigmoid(model(X_te)).cpu().numpy()
    y_pred     = (y_prob >= 0.5).astype(int)
    infer_time = time.time() - t0

    metrics = compute_metrics(y_test.astype(int), y_pred)
    metrics['train_time'] = train_time
    metrics['infer_time'] = infer_time
    return metrics, model
# Out:
# Using device: mps

# %%
import os
import numpy as np
import copy

# ══════════════════════════════════════════════════════════════
# GRU FINAL EXPERIMENTS — TOMEK + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best params: units=64, layers=1, dropout=0.1, lr=0.001, batch_size=64

# Datasets:
#   tomek_smote_balanced
#   tomek_rus8000_smote8000
#   tomek_rus2000_smote2000
#   tomek_rus500_smote500
# ══════════════════════════════════════════════════════════════

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best GRU hyperparameters
# ---------------------------------------------------------
best_params = {
    "units": 64,
    "layers": 1,
    "dropout": 0.1,
    "lr": 0.001,
    "batch_size": 64
}

TARGET_VARIANTS = [
    "tomek_smote_balanced",
    "tomek_rus8000_smote8000",
    "tomek_rus2000_smote2000",
    "tomek_rus500_smote500",
]

print(f"{'═' * 70}")
print("  Classifier : GRU (PyTorch)")
print("  Experiment : Tomek + SMOTE / RUS + SMOTE")
print(f"  Best params: {best_params}")
print(f"{'═' * 70}")


# ---------------------------------------------------------
# Run final GRU experiments on SMOTE datasets
# ---------------------------------------------------------
all_gru_smote_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_smote[dataset_key]

    timesteps = d["X_train"].shape[1]

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    cr = train_counts[0] / train_counts[1]

    print("\n" + "─" * 70)
    print(f"Dataset   : {dataset_key}")
    print(f"Timesteps : {timesteps}")
    print(f"Train     : {d['X_train'].shape} | Non-SEP={train_counts[0]} | SEP={train_counts[1]}")
    print(f"Val       : {d['X_val'].shape} | Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test      : {d['X_test'].shape} | Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print(f"Ratio     : {cr:.1f}:1")
    print(f"Params    : {best_params}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        print(f"Run {run + 1} …", flush=True)

        metrics, _ = train_and_evaluate_gru(
            copy.deepcopy(best_params),
            d["X_train"], d["y_train"],
            d["X_val"],   d["y_val"],
            d["X_test"],  d["y_test"],
            class_ratio=cr
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.1f}s"
        )

    all_gru_smote_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"gru_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"GRU | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("GRU Tomek + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Train N':>10} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)
print("─" * 105)

for dataset_key, metrics_list in all_gru_smote_results.items():

    d = datasets_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1]

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{len(d['y_train']):>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest GRU Tomek + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Params  : {best_params}")

print("\n✅ All GRU Tomek + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
#   Classifier : GRU (PyTorch)
#   Experiment : Tomek + SMOTE / RUS + SMOTE
#   Best params: {'units': 64, 'layers': 1, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_smote_balanced
# Timesteps : 288
# Train     : (24646, 288, 10) | Non-SEP=12323 | SEP=12323
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 64, 'layers': 1, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.2768 | F1=0.1905 | Recall=0.2941 | Precision=0.1408 | Train=285.6s
# Run 2 …
# Run 2: TSS=0.0814 | F1=0.0984 | Recall=0.0882 | Precision=0.1111 | Train=414.0s
#
# ───────────────────────────────────────────────────────
#   GRU | tomek_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=10  TN=3464  FP=61  FN=24
#          TSS=0.2768  FAR=0.8592  Bias=2.09
#          HSS1=-1.5000  HSS2=0.1799  GSS=0.0988
#          Recall=0.2941  Precision=0.1408  F1=0.1905  Acc=0.9761
#          Train=285.57s  Infer=0.1881s
#
#   Run 2: TP=3  TN=3501  FP=24  FN=31
#          TSS=0.0814  FAR=0.8889  Bias=0.79
#          HSS1=-0.6176  HSS2=0.0907  GSS=0.0475
#          Recall=0.0882  Precision=0.1111  F1=0.0984  Acc=0.9845
#          Train=413.97s  Infer=0.1995s
#
#   ── Average of 2 runs ──
#   tss          : 0.1791
#   far          : 0.8740
#   bias         : 1.4412
#   hss1         : -1.0588
#   hss2         : 0.1353
#   gss          : 0.0732
#   recall       : 0.1912
#   precision    : 0.1260
#   f1           : 0.1444
#   accuracy     : 0.9803
#   train_time   : 349.7663
#   infer_time   : 0.1938
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus8000_smote8000
# Timesteps : 288
# Train     : (16000, 288, 10) | Non-SEP=8000 | SEP=8000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 64, 'layers': 1, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.3045 | F1=0.1964 | Recall=0.3235 | Precision=0.1410 | Train=282.3s
# Run 2 …
# Run 2: TSS=0.2796 | F1=0.2105 | Recall=0.2941 | Precision=0.1639 | Train=331.1s
#
# ───────────────────────────────────────────────────────
#   GRU | tomek_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=11  TN=3458  FP=67  FN=23
#          TSS=0.3045  FAR=0.8590  Bias=2.29
#          HSS1=-1.6471  HSS2=0.1856  GSS=0.1023
#          Recall=0.3235  Precision=0.1410  F1=0.1964  Acc=0.9747
#          Train=282.32s  Infer=0.1896s
#
#   Run 2: TP=10  TN=3474  FP=51  FN=24
#          TSS=0.2796  FAR=0.8361  Bias=1.79
#          HSS1=-1.2059  HSS2=0.2007  GSS=0.1116
#          Recall=0.2941  Precision=0.1639  F1=0.2105  Acc=0.9789
#          Train=331.12s  Infer=0.1806s
#
#   ── Average of 2 runs ──
#   tss          : 0.2921
#   far          : 0.8475
#   bias         : 2.0441
#   hss1         : -1.4265
#   hss2         : 0.1932
#   gss          : 0.1069
#   recall       : 0.3088
#   precision    : 0.1525
#   f1           : 0.2035
#   accuracy     : 0.9768
#   train_time   : 306.7215
#   infer_time   : 0.1851
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus2000_smote2000
# Timesteps : 288
# Train     : (4000, 288, 10) | Non-SEP=2000 | SEP=2000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 64, 'layers': 1, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.2697 | F1=0.1538 | Recall=0.2941 | Precision=0.1042 | Train=99.5s
# Run 2 …
# Run 2: TSS=0.6692 | F1=0.1712 | Recall=0.7353 | Precision=0.0969 | Train=61.5s
#
# ───────────────────────────────────────────────────────
#   GRU | tomek_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=10  TN=3439  FP=86  FN=24
#          TSS=0.2697  FAR=0.8958  Bias=2.82
#          HSS1=-2.2353  HSS2=0.1417  GSS=0.0763
#          Recall=0.2941  Precision=0.1042  F1=0.1538  Acc=0.9691
#          Train=99.54s  Infer=0.1841s
#
#   Run 2: TP=25  TN=3292  FP=233  FN=9
#          TSS=0.6692  FAR=0.9031  Bias=7.59
#          HSS1=-6.1176  HSS2=0.1570  GSS=0.0852
#          Recall=0.7353  Precision=0.0969  F1=0.1712  Acc=0.9320
#          Train=61.50s  Infer=0.1842s
#
#   ── Average of 2 runs ──
#   tss          : 0.4695
#   far          : 0.8995
#   bias         : 5.2059
#   hss1         : -4.1765
#   hss2         : 0.1494
#   gss          : 0.0807
#   recall       : 0.5147
#   precision    : 0.1005
#   f1           : 0.1625
#   accuracy     : 0.9505
#   train_time   : 80.5174
#   infer_time   : 0.1841
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus500_smote500
# Timesteps : 288
# Train     : (1000, 288, 10) | Non-SEP=500 | SEP=500
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : {'units': 64, 'layers': 1, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.6097 | F1=0.1209 | Recall=0.7059 | Precision=0.0661 | Train=21.5s
# Run 2 …
# Run 2: TSS=0.6044 | F1=0.0832 | Recall=0.7647 | Precision=0.0440 | Train=9.8s
#
# ───────────────────────────────────────────────────────
#   GRU | tomek_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=24  TN=3186  FP=339  FN=10
#          TSS=0.6097  FAR=0.9339  Bias=10.68
#          HSS1=-9.2647  HSS2=0.1053  GSS=0.0556
#          Recall=0.7059  Precision=0.0661  F1=0.1209  Acc=0.9019
#          Train=21.45s  Infer=0.1795s
#
#   Run 2: TP=26  TN=2960  FP=565  FN=8
#          TSS=0.6044  FAR=0.9560  Bias=17.38
#          HSS1=-15.8529  HSS2=0.0663  GSS=0.0343
#          Recall=0.7647  Precision=0.0440  F1=0.0832  Acc=0.8390
#          Train=9.80s  Infer=0.1801s
#
#   ── Average of 2 runs ──
#   tss          : 0.6071
#   far          : 0.9449
#   bias         : 14.0294
#   hss1         : -12.5588
#   hss2         : 0.0858
#   gss          : 0.0449
#   recall       : 0.7353
#   precision    : 0.0551
#   f1           : 0.1021
#   accuracy     : 0.8705
#   train_time   : 15.6258
#   infer_time   : 0.1798
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# GRU Tomek + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                       Train N  Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# tomek_smote_balanced            24646    12323    12323       1.0x     0.1791     0.1444       0.1912
# tomek_rus8000_smote8000         16000     8000     8000       1.0x     0.2921     0.2035       0.3088
# tomek_rus2000_smote2000          4000     2000     2000       1.0x     0.4695     0.1625       0.5147
# tomek_rus500_smote500            1000      500      500       1.0x     0.6071     0.1021       0.7353
#
# Best GRU Tomek + SMOTE dataset:
#   Dataset : tomek_rus500_smote500
#   Avg TSS : 0.6071
#   Params  : {'units': 64, 'layers': 1, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
#
# ✅ All GRU Tomek + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/Documents/Claude/SEP_DataAugmentation/results/
# Files: ['gru_hybrid.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_nonorm.txt', 'gru_tomek_nonsep_2000.txt', 'gru_tomek_nonsep_500.txt', 'gru_tomek_nonsep_8000.txt', 'gru_tomek_rus2000_smote2000.txt', 'gru_tomek_rus500_smote500.txt', 'gru_tomek_rus8000_smote8000.txt', 'gru_tomek_smote_balanced.txt', 'gru_zscore_all.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_nonorm.txt', 'inceptiontime_tomek_nonsep_2000.txt', 'inceptiontime_tomek_nonsep_500.txt', 'inceptiontime_tomek_nonsep_8000.txt', 'inceptiontime_zscore_all.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_nonorm.txt', 'patchtst_tomek_nonsep_2000.txt', 'patchtst_tomek_nonsep_500.txt', 'patchtst_tomek_nonsep_8000.txt', 'patchtst_zscore_all.txt', 'svm_hybrid.txt', 'svm_hybrid_enn.txt', 'svm_hybrid_nearmiss.txt', 'svm_hybrid_tomek.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_nonorm.txt', 'svm_tomek_nonsep_2000.txt', 'svm_tomek_nonsep_500.txt', 'svm_tomek_nonsep_8000.txt', 'svm_tomek_rus2000_smote2000.txt', 'svm_tomek_rus500_smote500.txt', 'svm_tomek_rus8000_smote8000.txt', 'svm_tomek_smote_balanced.txt', 'svm_zscore_all.txt']

# %% [markdown]
# ### PatchTST

# %%
import os
import time
import copy
import warnings
import numpy as np

import torch
import torch.nn as nn
from transformers import PatchTSTConfig, PatchTSTForClassification

warnings.filterwarnings("ignore")

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")


def patchtst_label(p):
    return (
        f"patch={p['patch_length']}  "
        f"stride={p['patch_stride']}  "
        f"d={p['d_model']}  "
        f"heads={p['num_attention_heads']}  "
        f"layers={p['num_hidden_layers']}  "
        f"drop={p['dropout']}  "
        f"lr={p['lr']}  "
        f"bs={p['batch_size']}"
    )


def build_patchtst_model(params, seq_len, n_channels):
    config = PatchTSTConfig(
        num_input_channels=n_channels,
        context_length=seq_len,
        num_targets=2,

        patch_length=params["patch_length"],
        patch_stride=params["patch_stride"],

        d_model=params["d_model"],
        num_attention_heads=params["num_attention_heads"],
        num_hidden_layers=params["num_hidden_layers"],
        ffn_dim=params["ffn_dim"],

        attention_dropout=params["dropout"],
        positional_dropout=params["dropout"],
        ff_dropout=params["dropout"],
        head_dropout=params["dropout"],

        pooling_type="mean",
        use_cls_token=True,
        norm_type="layernorm",
        channel_attention=True,
        problem_type="single_label_classification",
        scaling=None,
    )

    return PatchTSTForClassification(config)


def train_and_evaluate_patchtst(
    params,
    X_train, y_train,
    X_val, y_val,
    X_test, y_test,
    class_ratio,
    max_epochs=30,
    patience=3
):
    X_tr = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tr = torch.tensor(y_train, dtype=torch.long).to(device)

    X_va = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_va = torch.tensor(y_val, dtype=torch.long).to(device)

    X_te = torch.tensor(X_test, dtype=torch.float32).to(device)

    seq_len = X_train.shape[1]
    n_channels = X_train.shape[2]

    model = build_patchtst_model(
        params,
        seq_len=seq_len,
        n_channels=n_channels
    ).to(device)

    class_weights = torch.tensor(
        [1.0, float(class_ratio)],
        dtype=torch.float32
    ).to(device)

    criterion = nn.CrossEntropyLoss(weight=class_weights)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=params["lr"],
        weight_decay=1e-4
    )

    batch_size = params["batch_size"]
    n_samples = X_tr.shape[0]

    best_val_loss = float("inf")
    best_state = None
    patience_count = 0

    t0 = time.time()

    for epoch in range(max_epochs):
        model.train()

        perm = torch.randperm(n_samples, device=device)

        for i in range(0, n_samples, batch_size):
            idx = perm[i:i + batch_size]

            xb = X_tr[idx]
            yb = y_tr[idx]

            optimizer.zero_grad()

            outputs = model(past_values=xb)
            logits = outputs.prediction_logits

            loss = criterion(logits, yb)
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_outputs = model(past_values=X_va)
            val_logits = val_outputs.prediction_logits
            val_loss = criterion(val_logits, y_va).item()

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = copy.deepcopy(model.state_dict())
            patience_count = 0
        else:
            patience_count += 1
            if patience_count >= patience:
                break

    train_time = time.time() - t0

    if best_state is not None:
        model.load_state_dict(best_state)

    model.eval()
    t0 = time.time()

    with torch.no_grad():
        test_outputs = model(past_values=X_te)
        test_logits = test_outputs.prediction_logits
        y_pred = torch.argmax(test_logits, dim=1).cpu().numpy()

    infer_time = time.time() - t0

    metrics = compute_metrics(y_test.astype(int), y_pred.astype(int))
    metrics["train_time"] = train_time
    metrics["infer_time"] = infer_time

    return metrics, model
# Out:
# Using device: mps

# %%
# ══════════════════════════════════════════════════════════════
# PATCHTST FINAL EXPERIMENTS — TOMEK + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best params: patch=6, stride=6, d=32, heads=4, layers=1,
#              ffn=128, dropout=0.2, lr=0.001, batch_size=128

# Datasets:
#   tomek_smote_balanced
#   tomek_rus8000_smote8000
#   tomek_rus2000_smote2000
#   tomek_rus500_smote500
# ══════════════════════════════════════════════════════════════

import os
import copy
import numpy as np

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best PatchTST hyperparameters
# ---------------------------------------------------------
best_params = {
    "patch_length": 6,
    "patch_stride": 6,
    "d_model": 32,
    "num_attention_heads": 4,
    "num_hidden_layers": 1,
    "ffn_dim": 128,
    "dropout": 0.2,
    "lr": 0.001,
    "batch_size": 128,
}

TARGET_VARIANTS = [
    "tomek_smote_balanced",
    "tomek_rus8000_smote8000",
    "tomek_rus2000_smote2000",
    "tomek_rus500_smote500",
]


def patchtst_label(p):
    return (
        f"patch={p['patch_length']}  "
        f"stride={p['patch_stride']}  "
        f"d={p['d_model']}  "
        f"heads={p['num_attention_heads']}  "
        f"layers={p['num_hidden_layers']}  "
        f"drop={p['dropout']}  "
        f"lr={p['lr']}  "
        f"bs={p['batch_size']}"
    )


print(f"{'═' * 70}")
print("  Classifier : Hugging Face PatchTST")
print("  Experiment : Tomek + SMOTE / RUS + SMOTE")
print(f"  Best params: {patchtst_label(best_params)}")
print(f"{'═' * 70}")


# ---------------------------------------------------------
# Run final PatchTST experiments on SMOTE datasets
# ---------------------------------------------------------
all_patchtst_smote_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_smote[dataset_key]

    timesteps = d["X_train"].shape[1]

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    cr = train_counts[0] / train_counts[1]

    print("\n" + "─" * 70)
    print(f"Dataset   : {dataset_key}")
    print(f"Timesteps : {timesteps}")
    print(f"Train     : {d['X_train'].shape} | Non-SEP={train_counts[0]} | SEP={train_counts[1]}")
    print(f"Val       : {d['X_val'].shape} | Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test      : {d['X_test'].shape} | Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print(f"Ratio     : {cr:.1f}:1")
    print(f"Params    : {patchtst_label(best_params)}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        print(f"Run {run + 1} …", flush=True)

        metrics, _ = train_and_evaluate_patchtst(
            copy.deepcopy(best_params),
            d["X_train"], d["y_train"],
            d["X_val"],   d["y_val"],
            d["X_test"],  d["y_test"],
            class_ratio=cr,
            max_epochs=30,
            patience=3
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.1f}s"
        )

    all_patchtst_smote_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"patchtst_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"PatchTST | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("PatchTST Tomek + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Train N':>10} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)

print("─" * 105)

for dataset_key, metrics_list in all_patchtst_smote_results.items():

    d = datasets_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1]

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{len(d['y_train']):>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest PatchTST Tomek + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Params  : {patchtst_label(best_params)}")

print("\n✅ All PatchTST Tomek + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
#   Classifier : Hugging Face PatchTST
#   Experiment : Tomek + SMOTE / RUS + SMOTE
#   Best params: patch=6  stride=6  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_smote_balanced
# Timesteps : 288
# Train     : (24646, 288, 10) | Non-SEP=12323 | SEP=12323
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=6  stride=6  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.5809 | F1=0.1168 | Recall=0.6765 | Precision=0.0639 | Train=75.3s
# Run 2 …
# Run 2: TSS=0.5812 | F1=0.1170 | Recall=0.6765 | Precision=0.0641 | Train=75.5s
#
# ───────────────────────────────────────────────────────
#   PatchTST | tomek_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=23  TN=3188  FP=337  FN=11
#          TSS=0.5809  FAR=0.9361  Bias=10.59
#          HSS1=-9.2353  HSS2=0.1011  GSS=0.0532
#          Recall=0.6765  Precision=0.0639  F1=0.1168  Acc=0.9022
#          Train=75.30s  Infer=3.0385s
#
#   Run 2: TP=23  TN=3189  FP=336  FN=11
#          TSS=0.5812  FAR=0.9359  Bias=10.56
#          HSS1=-9.2059  HSS2=0.1014  GSS=0.0534
#          Recall=0.6765  Precision=0.0641  F1=0.1170  Acc=0.9025
#          Train=75.53s  Infer=2.4457s
#
#   ── Average of 2 runs ──
#   tss          : 0.5810
#   far          : 0.9360
#   bias         : 10.5735
#   hss1         : -9.2206
#   hss2         : 0.1012
#   gss          : 0.0533
#   recall       : 0.6765
#   precision    : 0.0640
#   f1           : 0.1169
#   accuracy     : 0.9024
#   train_time   : 75.4172
#   infer_time   : 2.7421
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus8000_smote8000
# Timesteps : 288
# Train     : (16000, 288, 10) | Non-SEP=8000 | SEP=8000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=6  stride=6  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.3829 | F1=0.0891 | Recall=0.4706 | Precision=0.0492 | Train=64.1s
# Run 2 …
# Run 2: TSS=0.4036 | F1=0.1119 | Recall=0.4706 | Precision=0.0635 | Train=88.2s
#
# ───────────────────────────────────────────────────────
#   PatchTST | tomek_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=16  TN=3216  FP=309  FN=18
#          TSS=0.3829  FAR=0.9508  Bias=9.56
#          HSS1=-8.6176  HSS2=0.0731  GSS=0.0379
#          Recall=0.4706  Precision=0.0492  F1=0.0891  Acc=0.9081
#          Train=64.09s  Infer=7.3763s
#
#   Run 2: TP=16  TN=3289  FP=236  FN=18
#          TSS=0.4036  FAR=0.9365  Bias=7.41
#          HSS1=-6.4706  HSS2=0.0967  GSS=0.0508
#          Recall=0.4706  Precision=0.0635  F1=0.1119  Acc=0.9286
#          Train=88.23s  Infer=12.5214s
#
#   ── Average of 2 runs ──
#   tss          : 0.3933
#   far          : 0.9436
#   bias         : 8.4853
#   hss1         : -7.5441
#   hss2         : 0.0849
#   gss          : 0.0444
#   recall       : 0.4706
#   precision    : 0.0564
#   f1           : 0.1005
#   accuracy     : 0.9184
#   train_time   : 76.1602
#   infer_time   : 9.9489
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus2000_smote2000
# Timesteps : 288
# Train     : (4000, 288, 10) | Non-SEP=2000 | SEP=2000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=6  stride=6  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.5760 | F1=0.0930 | Recall=0.7059 | Precision=0.0498 | Train=48.1s
# Run 2 …
# Run 2: TSS=0.5254 | F1=0.1105 | Recall=0.6176 | Precision=0.0607 | Train=45.4s
#
# ───────────────────────────────────────────────────────
#   PatchTST | tomek_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=24  TN=3067  FP=458  FN=10
#          TSS=0.5760  FAR=0.9502  Bias=14.18
#          HSS1=-12.7647  HSS2=0.0765  GSS=0.0398
#          Recall=0.7059  Precision=0.0498  F1=0.0930  Acc=0.8685
#          Train=48.12s  Infer=14.9387s
#
#   Run 2: TP=21  TN=3200  FP=325  FN=13
#          TSS=0.5254  FAR=0.9393  Bias=10.18
#          HSS1=-8.9412  HSS2=0.0948  GSS=0.0497
#          Recall=0.6176  Precision=0.0607  F1=0.1105  Acc=0.9050
#          Train=45.42s  Infer=4.1427s
#
#   ── Average of 2 runs ──
#   tss          : 0.5507
#   far          : 0.9448
#   bias         : 12.1765
#   hss1         : -10.8529
#   hss2         : 0.0857
#   gss          : 0.0448
#   recall       : 0.6618
#   precision    : 0.0552
#   f1           : 0.1018
#   accuracy     : 0.8868
#   train_time   : 46.7690
#   infer_time   : 9.5407
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus500_smote500
# Timesteps : 288
# Train     : (1000, 288, 10) | Non-SEP=500 | SEP=500
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : patch=6  stride=6  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.6187 | F1=0.1064 | Recall=0.7353 | Precision=0.0573 | Train=19.9s
# Run 2 …
# Run 2: TSS=0.5937 | F1=0.0896 | Recall=0.7353 | Precision=0.0477 | Train=12.8s
#
# ───────────────────────────────────────────────────────
#   PatchTST | tomek_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=25  TN=3114  FP=411  FN=9
#          TSS=0.6187  FAR=0.9427  Bias=12.82
#          HSS1=-11.3529  HSS2=0.0903  GSS=0.0473
#          Recall=0.7353  Precision=0.0573  F1=0.1064  Acc=0.8820
#          Train=19.93s  Infer=6.7766s
#
#   Run 2: TP=25  TN=3026  FP=499  FN=9
#          TSS=0.5937  FAR=0.9523  Bias=15.41
#          HSS1=-13.9412  HSS2=0.0730  GSS=0.0379
#          Recall=0.7353  Precision=0.0477  F1=0.0896  Acc=0.8573
#          Train=12.79s  Infer=6.1965s
#
#   ── Average of 2 runs ──
#   tss          : 0.6062
#   far          : 0.9475
#   bias         : 14.1176
#   hss1         : -12.6471
#   hss2         : 0.0816
#   gss          : 0.0426
#   recall       : 0.7353
#   precision    : 0.0525
#   f1           : 0.0980
#   accuracy     : 0.8696
#   train_time   : 16.3628
#   infer_time   : 6.4866
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# PatchTST Tomek + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                       Train N  Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# tomek_smote_balanced            24646    12323    12323       1.0x     0.5810     0.1169       0.6765
# tomek_rus8000_smote8000         16000     8000     8000       1.0x     0.3933     0.1005       0.4706
# tomek_rus2000_smote2000          4000     2000     2000       1.0x     0.5507     0.1018       0.6618
# tomek_rus500_smote500            1000      500      500       1.0x     0.6062     0.0980       0.7353
#
# Best PatchTST Tomek + SMOTE dataset:
#   Dataset : tomek_rus500_smote500
#   Avg TSS : 0.6062
#   Params  : patch=6  stride=6  d=32  heads=4  layers=1  drop=0.2  lr=0.001  bs=128
#
# ✅ All PatchTST Tomek + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/Documents/Claude/SEP_DataAugmentation/results/
# Files: ['gru_hybrid.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_nonorm.txt', 'gru_tomek_nonsep_2000.txt', 'gru_tomek_nonsep_500.txt', 'gru_tomek_nonsep_8000.txt', 'gru_tomek_rus2000_smote2000.txt', 'gru_tomek_rus500_smote500.txt', 'gru_tomek_rus8000_smote8000.txt', 'gru_tomek_smote_balanced.txt', 'gru_zscore_all.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_nonorm.txt', 'inceptiontime_tomek_nonsep_2000.txt', 'inceptiontime_tomek_nonsep_500.txt', 'inceptiontime_tomek_nonsep_8000.txt', 'inceptiontime_zscore_all.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_nonorm.txt', 'patchtst_tomek_nonsep_2000.txt', 'patchtst_tomek_nonsep_500.txt', 'patchtst_tomek_nonsep_8000.txt', 'patchtst_tomek_rus2000_smote2000.txt', 'patchtst_tomek_rus500_smote500.txt', 'patchtst_tomek_rus8000_smote8000.txt', 'patchtst_tomek_smote_balanced.txt', 'patchtst_zscore_all.txt', 'svm_hybrid.txt', 'svm_hybrid_enn.txt', 'svm_hybrid_nearmiss.txt', 'svm_hybrid_tomek.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_nonorm.txt', 'svm_tomek_nonsep_2000.txt', 'svm_tomek_nonsep_500.txt', 'svm_tomek_nonsep_8000.txt', 'svm_tomek_rus2000_smote2000.txt', 'svm_tomek_rus500_smote500.txt', 'svm_tomek_rus8000_smote8000.txt', 'svm_tomek_smote_balanced.txt', 'svm_zscore_all.txt']

# %% [markdown]
# ### InceptionTime

# %%
import os
import time
import copy
import warnings
import numpy as np

import torch
import torch.nn as nn

warnings.filterwarnings("ignore")

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")


# ══════════════════════════════════════════════════════════════
# INCEPTIONTIME MODEL
# ══════════════════════════════════════════════════════════════

class InceptionModule(nn.Module):
    def __init__(
        self,
        in_channels,
        out_channels=32,
        kernel_sizes=(9, 19, 39),
        bottleneck_channels=32
    ):
        super(InceptionModule, self).__init__()

        if in_channels > 1:
            self.bottleneck = nn.Conv1d(
                in_channels,
                bottleneck_channels,
                kernel_size=1,
                bias=False
            )
            conv_in_channels = bottleneck_channels
        else:
            self.bottleneck = nn.Identity()
            conv_in_channels = in_channels

        self.conv_list = nn.ModuleList([
            nn.Conv1d(
                conv_in_channels,
                out_channels,
                kernel_size=k,
                padding=k // 2,
                bias=False
            )
            for k in kernel_sizes
        ])

        self.maxpool_conv = nn.Sequential(
            nn.MaxPool1d(kernel_size=3, stride=1, padding=1),
            nn.Conv1d(in_channels, out_channels, kernel_size=1, bias=False)
        )

        total_out_channels = out_channels * (len(kernel_sizes) + 1)

        self.bn = nn.BatchNorm1d(total_out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x_bottleneck = self.bottleneck(x)

        conv_outputs = [
            conv(x_bottleneck)
            for conv in self.conv_list
        ]

        pool_output = self.maxpool_conv(x)

        out = torch.cat(conv_outputs + [pool_output], dim=1)
        out = self.bn(out)
        out = self.relu(out)

        return out


class InceptionBlock(nn.Module):
    def __init__(self, in_channels, out_channels=32, depth=3, use_residual=True):
        super(InceptionBlock, self).__init__()

        self.use_residual = use_residual
        self.depth = depth

        modules = []
        current_channels = in_channels

        for _ in range(depth):
            module = InceptionModule(
                in_channels=current_channels,
                out_channels=out_channels
            )
            modules.append(module)

            current_channels = out_channels * 4

        self.inception_modules = nn.ModuleList(modules)

        if use_residual:
            self.residual = nn.Sequential(
                nn.Conv1d(in_channels, current_channels, kernel_size=1, bias=False),
                nn.BatchNorm1d(current_channels)
            )
            self.relu = nn.ReLU()

    def forward(self, x):
        residual = x

        out = x
        for module in self.inception_modules:
            out = module(out)

        if self.use_residual:
            residual = self.residual(residual)
            out = self.relu(out + residual)

        return out


class InceptionTimeClassifier(nn.Module):
    def __init__(self, input_channels, out_channels=32, depth=6, dropout=0.3):
        super(InceptionTimeClassifier, self).__init__()

        block_depth = max(1, depth // 2)

        self.block1 = InceptionBlock(
            in_channels=input_channels,
            out_channels=out_channels,
            depth=block_depth,
            use_residual=True
        )

        block1_channels = out_channels * 4

        self.block2 = InceptionBlock(
            in_channels=block1_channels,
            out_channels=out_channels,
            depth=block_depth,
            use_residual=True
        )

        final_channels = out_channels * 4

        self.gap = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(final_channels, 1)

    def forward(self, x):
        # Input shape: (batch, timesteps, features)
        # Conv1d expects: (batch, features, timesteps)
        x = x.permute(0, 2, 1)

        x = self.block1(x)
        x = self.block2(x)

        x = self.gap(x).squeeze(-1)
        x = self.dropout(x)

        return self.fc(x).squeeze()


# ══════════════════════════════════════════════════════════════
# TRAIN AND EVALUATE INCEPTIONTIME
# ══════════════════════════════════════════════════════════════

def train_and_evaluate_inception(
    params,
    X_train, y_train,
    X_val, y_val,
    X_test, y_test,
    class_ratio,
    max_epochs=30,
    patience=3
):
    X_tr = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_tr = torch.tensor(y_train, dtype=torch.float32).to(device)

    X_va = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_va = torch.tensor(y_val, dtype=torch.float32).to(device)

    X_te = torch.tensor(X_test, dtype=torch.float32).to(device)

    input_channels = X_train.shape[2]

    model = InceptionTimeClassifier(
        input_channels=input_channels,
        out_channels=params["out_channels"],
        depth=params["depth"],
        dropout=params["dropout"]
    ).to(device)

    pos_weight = torch.tensor([float(class_ratio)], dtype=torch.float32).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=params["lr"],
        weight_decay=1e-4
    )

    batch_size = params["batch_size"]
    n_samples = X_tr.shape[0]

    best_val_loss = float("inf")
    best_state = None
    patience_count = 0

    t0 = time.time()

    for epoch in range(max_epochs):
        model.train()

        perm = torch.randperm(n_samples, device=device)

        for i in range(0, n_samples, batch_size):
            idx = perm[i:i + batch_size]

            xb = X_tr[idx]
            yb = y_tr[idx]

            optimizer.zero_grad()

            logits = model(xb)
            loss = criterion(logits, yb)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_logits = model(X_va)
            val_loss = criterion(val_logits, y_va).item()

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = copy.deepcopy(model.state_dict())
            patience_count = 0
        else:
            patience_count += 1

            if patience_count >= patience:
                break

    train_time = time.time() - t0

    if best_state is not None:
        model.load_state_dict(best_state)

    model.eval()
    t0 = time.time()

    with torch.no_grad():
        y_prob = torch.sigmoid(model(X_te)).cpu().numpy()

    y_pred = (y_prob >= 0.5).astype(int)
    infer_time = time.time() - t0

    metrics = compute_metrics(y_test.astype(int), y_pred.astype(int))
    metrics["train_time"] = train_time
    metrics["infer_time"] = infer_time

    return metrics, model
# Out:
# Using device: mps

# %%
# ══════════════════════════════════════════════════════════════
# INCEPTIONTIME FINAL EXPERIMENTS — TOMEK + SMOTE / RUS + SMOTE
# Uses fixed best hyperparameters selected previously
# Best params: channels=16, depth=8, dropout=0.2, lr=0.001, batch_size=128

# Datasets:
#   tomek_smote_balanced
#   tomek_rus8000_smote8000
#   tomek_rus2000_smote2000
#   tomek_rus500_smote500
# ══════════════════════════════════════════════════════════════

import os
import copy
import numpy as np

RESULTS_DIR = "./results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# ---------------------------------------------------------
# Fixed best InceptionTime hyperparameters
# ---------------------------------------------------------
best_params = {
    "out_channels": 16,
    "depth": 8,
    "dropout": 0.2,
    "lr": 0.001,
    "batch_size": 128
}

TARGET_VARIANTS = [
    "tomek_smote_balanced",
    "tomek_rus8000_smote8000",
    "tomek_rus2000_smote2000",
    "tomek_rus500_smote500",
]


def inception_label(p):
    return (
        f"channels={p['out_channels']}  "
        f"depth={p['depth']}  "
        f"drop={p['dropout']}  "
        f"lr={p['lr']}  "
        f"bs={p['batch_size']}"
    )


print(f"{'═' * 70}")
print("  Classifier : InceptionTime")
print("  Experiment : Tomek + SMOTE / RUS + SMOTE")
print(f"  Best params: {inception_label(best_params)}")
print(f"{'═' * 70}")


# ---------------------------------------------------------
# Run final InceptionTime experiments on SMOTE datasets
# ---------------------------------------------------------
all_inception_smote_results = {}

for dataset_key in TARGET_VARIANTS:

    if dataset_key not in datasets_smote:
        print(f"[{dataset_key}] not found — skipping")
        continue

    d = datasets_smote[dataset_key]

    timesteps = d["X_train"].shape[1]

    train_counts = np.bincount(d["y_train"].astype(int), minlength=2)
    val_counts   = np.bincount(d["y_val"].astype(int), minlength=2)
    test_counts  = np.bincount(d["y_test"].astype(int), minlength=2)

    cr = train_counts[0] / train_counts[1]

    print("\n" + "─" * 70)
    print(f"Dataset   : {dataset_key}")
    print(f"Timesteps : {timesteps}")
    print(f"Train     : {d['X_train'].shape} | Non-SEP={train_counts[0]} | SEP={train_counts[1]}")
    print(f"Val       : {d['X_val'].shape} | Non-SEP={val_counts[0]} | SEP={val_counts[1]}")
    print(f"Test      : {d['X_test'].shape} | Non-SEP={test_counts[0]} | SEP={test_counts[1]}")
    print(f"Ratio     : {cr:.1f}:1")
    print(f"Params    : {inception_label(best_params)}")
    print("─" * 70)

    metrics_list = []

    for run in range(2):

        print(f"Run {run + 1} …", flush=True)

        metrics, _ = train_and_evaluate_inception(
            copy.deepcopy(best_params),
            d["X_train"], d["y_train"],
            d["X_val"],   d["y_val"],
            d["X_test"],  d["y_test"],
            class_ratio=cr,
            max_epochs=30,
            patience=3
        )

        metrics_list.append(metrics)

        precision_text = (
            f" | Precision={metrics['precision']:.4f}"
            if "precision" in metrics else ""
        )

        print(
            f"Run {run + 1}: "
            f"TSS={metrics['tss']:.4f} | "
            f"F1={metrics['f1']:.4f} | "
            f"Recall={metrics['recall']:.4f}"
            f"{precision_text} | "
            f"Train={metrics['train_time']:.1f}s"
        )

    all_inception_smote_results[dataset_key] = metrics_list

    filepath = os.path.join(RESULTS_DIR, f"inceptiontime_{dataset_key}.txt")
    save_results(metrics_list, filepath)
    print_results(metrics_list, f"InceptionTime | {dataset_key}")


# ---------------------------------------------------------
# Select best SMOTE dataset by average TSS
# ---------------------------------------------------------
best_dataset = None
best_avg_tss = -np.inf

print("\n" + "═" * 70)
print("InceptionTime Tomek + SMOTE summary")
print("═" * 70)

print(
    f"{'Dataset':<26} "
    f"{'Train N':>10} "
    f"{'Non-SEP':>8} "
    f"{'SEP':>8} "
    f"{'Ratio':>10} "
    f"{'Avg TSS':>10} "
    f"{'Avg F1':>10} "
    f"{'Avg Recall':>12}"
)

print("─" * 105)

for dataset_key, metrics_list in all_inception_smote_results.items():

    d = datasets_smote[dataset_key]

    counts = np.bincount(d["y_train"].astype(int), minlength=2)
    ratio = counts[0] / counts[1]

    avg_tss = np.mean([m["tss"] for m in metrics_list])
    avg_f1 = np.mean([m["f1"] for m in metrics_list])
    avg_recall = np.mean([m["recall"] for m in metrics_list])

    print(
        f"{dataset_key:<26} "
        f"{len(d['y_train']):>10} "
        f"{counts[0]:>8} "
        f"{counts[1]:>8} "
        f"{ratio:>9.1f}x "
        f"{avg_tss:>10.4f} "
        f"{avg_f1:>10.4f} "
        f"{avg_recall:>12.4f}"
    )

    if avg_tss > best_avg_tss:
        best_avg_tss = avg_tss
        best_dataset = dataset_key


print("\nBest InceptionTime Tomek + SMOTE dataset:")
print(f"  Dataset : {best_dataset}")
print(f"  Avg TSS : {best_avg_tss:.4f}")
print(f"  Params  : {inception_label(best_params)}")

print("\n✅ All InceptionTime Tomek + SMOTE experiments complete.")
print(f"Results saved to: {os.path.abspath(RESULTS_DIR)}/")
print(f"Files: {sorted([f for f in os.listdir(RESULTS_DIR) if f.endswith('.txt')])}")
# Out:
# ══════════════════════════════════════════════════════════════════════
#   Classifier : InceptionTime
#   Experiment : Tomek + SMOTE / RUS + SMOTE
#   Best params: channels=16  depth=8  drop=0.2  lr=0.001  bs=128
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_smote_balanced
# Timesteps : 288
# Train     : (24646, 288, 10) | Non-SEP=12323 | SEP=12323
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=8  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.0242 | F1=0.0253 | Recall=0.0588 | Precision=0.0161 | Train=219.3s
# Run 2 …
# Run 2: TSS=0.0229 | F1=0.0345 | Recall=0.0294 | Precision=0.0417 | Train=437.1s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | tomek_smote_balanced
# ───────────────────────────────────────────────────────
#   Run 1: TP=2  TN=3403  FP=122  FN=32
#          TSS=0.0242  FAR=0.9839  Bias=3.65
#          HSS1=-3.5294  HSS2=0.0105  GSS=0.0053
#          Recall=0.0588  Precision=0.0161  F1=0.0253  Acc=0.9567
#          Train=219.33s  Infer=1.0009s
#
#   Run 2: TP=1  TN=3502  FP=23  FN=33
#          TSS=0.0229  FAR=0.9583  Bias=0.71
#          HSS1=-0.6471  HSS2=0.0268  GSS=0.0136
#          Recall=0.0294  Precision=0.0417  F1=0.0345  Acc=0.9843
#          Train=437.08s  Infer=0.9313s
#
#   ── Average of 2 runs ──
#   tss          : 0.0236
#   far          : 0.9711
#   bias         : 2.1765
#   hss1         : -2.0882
#   hss2         : 0.0186
#   gss          : 0.0094
#   recall       : 0.0441
#   precision    : 0.0289
#   f1           : 0.0299
#   accuracy     : 0.9705
#   train_time   : 328.2024
#   infer_time   : 0.9661
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus8000_smote8000
# Timesteps : 288
# Train     : (16000, 288, 10) | Non-SEP=8000 | SEP=8000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=8  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.0647 | F1=0.0500 | Recall=0.0882 | Precision=0.0349 | Train=192.9s
# Run 2 …
# Run 2: TSS=-0.0077 | F1=0.0000 | Recall=0.0000 | Precision=0.0000 | Train=225.7s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | tomek_rus8000_smote8000
# ───────────────────────────────────────────────────────
#   Run 1: TP=3  TN=3442  FP=83  FN=31
#          TSS=0.0647  FAR=0.9651  Bias=2.53
#          HSS1=-2.3529  HSS2=0.0368  GSS=0.0188
#          Recall=0.0882  Precision=0.0349  F1=0.0500  Acc=0.9680
#          Train=192.88s  Infer=0.9219s
#
#   Run 2: TP=0  TN=3498  FP=27  FN=34
#          TSS=-0.0077  FAR=1.0000  Bias=0.79
#          HSS1=-0.7941  HSS2=-0.0085  GSS=-0.0042
#          Recall=0.0000  Precision=0.0000  F1=0.0000  Acc=0.9829
#          Train=225.70s  Infer=0.9489s
#
#   ── Average of 2 runs ──
#   tss          : 0.0285
#   far          : 0.9826
#   bias         : 1.6618
#   hss1         : -1.5735
#   hss2         : 0.0141
#   gss          : 0.0073
#   recall       : 0.0441
#   precision    : 0.0174
#   f1           : 0.0250
#   accuracy     : 0.9754
#   train_time   : 209.2921
#   infer_time   : 0.9354
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus2000_smote2000
# Timesteps : 288
# Train     : (4000, 288, 10) | Non-SEP=2000 | SEP=2000
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=8  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.0873 | F1=0.0552 | Recall=0.1176 | Precision=0.0360 | Train=53.3s
# Run 2 …
# Run 2: TSS=0.1408 | F1=0.0427 | Recall=0.2353 | Precision=0.0235 | Train=30.5s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | tomek_rus2000_smote2000
# ───────────────────────────────────────────────────────
#   Run 1: TP=4  TN=3418  FP=107  FN=30
#          TSS=0.0873  FAR=0.9640  Bias=3.26
#          HSS1=-3.0294  HSS2=0.0411  GSS=0.0210
#          Recall=0.1176  Precision=0.0360  F1=0.0552  Acc=0.9615
#          Train=53.27s  Infer=1.1628s
#
#   Run 2: TP=8  TN=3192  FP=333  FN=26
#          TSS=0.1408  FAR=0.9765  Bias=10.03
#          HSS1=-9.5588  HSS2=0.0257  GSS=0.0130
#          Recall=0.2353  Precision=0.0235  F1=0.0427  Acc=0.8991
#          Train=30.47s  Infer=0.8933s
#
#   ── Average of 2 runs ──
#   tss          : 0.1141
#   far          : 0.9703
#   bias         : 6.6471
#   hss1         : -6.2941
#   hss2         : 0.0334
#   gss          : 0.0170
#   recall       : 0.1765
#   precision    : 0.0297
#   f1           : 0.0489
#   accuracy     : 0.9303
#   train_time   : 41.8675
#   infer_time   : 1.0281
# ───────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# Dataset   : tomek_rus500_smote500
# Timesteps : 288
# Train     : (1000, 288, 10) | Non-SEP=500 | SEP=500
# Val       : (1780, 288, 10) | Non-SEP=1763 | SEP=17
# Test      : (3559, 288, 10) | Non-SEP=3525 | SEP=34
# Ratio     : 1.0:1
# Params    : channels=16  depth=8  drop=0.2  lr=0.001  bs=128
# ──────────────────────────────────────────────────────────────────────
# Run 1 …
# Run 1: TSS=0.3020 | F1=0.0644 | Recall=0.4118 | Precision=0.0349 | Train=18.4s
# Run 2 …
# Run 2: TSS=0.0595 | F1=0.0329 | Recall=0.1176 | Precision=0.0191 | Train=22.5s
#
# ───────────────────────────────────────────────────────
#   InceptionTime | tomek_rus500_smote500
# ───────────────────────────────────────────────────────
#   Run 1: TP=14  TN=3138  FP=387  FN=20
#          TSS=0.3020  FAR=0.9651  Bias=11.79
#          HSS1=-10.9706  HSS2=0.0476  GSS=0.0244
#          Recall=0.4118  Precision=0.0349  F1=0.0644  Acc=0.8856
#          Train=18.40s  Infer=0.9424s
#
#   Run 2: TP=4  TN=3320  FP=205  FN=30
#          TSS=0.0595  FAR=0.9809  Bias=6.15
#          HSS1=-5.9118  HSS2=0.0168  GSS=0.0085
#          Recall=0.1176  Precision=0.0191  F1=0.0329  Acc=0.9340
#          Train=22.51s  Infer=1.0047s
#
#   ── Average of 2 runs ──
#   tss          : 0.1807
#   far          : 0.9730
#   bias         : 8.9706
#   hss1         : -8.4412
#   hss2         : 0.0322
#   gss          : 0.0164
#   recall       : 0.2647
#   precision    : 0.0270
#   f1           : 0.0486
#   accuracy     : 0.9098
#   train_time   : 20.4517
#   infer_time   : 0.9736
# ───────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════
# InceptionTime Tomek + SMOTE summary
# ══════════════════════════════════════════════════════════════════════
# Dataset                       Train N  Non-SEP      SEP      Ratio    Avg TSS     Avg F1   Avg Recall
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────
# tomek_smote_balanced            24646    12323    12323       1.0x     0.0236     0.0299       0.0441
# tomek_rus8000_smote8000         16000     8000     8000       1.0x     0.0285     0.0250       0.0441
# tomek_rus2000_smote2000          4000     2000     2000       1.0x     0.1141     0.0489       0.1765
# tomek_rus500_smote500            1000      500      500       1.0x     0.1807     0.0486       0.2647
#
# Best InceptionTime Tomek + SMOTE dataset:
#   Dataset : tomek_rus500_smote500
#   Avg TSS : 0.1807
#   Params  : channels=16  depth=8  drop=0.2  lr=0.001  bs=128
#
# ✅ All InceptionTime Tomek + SMOTE experiments complete.
# Results saved to: /Users/samskanderi/Documents/Claude/SEP_DataAugmentation/results/
# Files: ['gru_hybrid.txt', 'gru_hybrid_enn.txt', 'gru_hybrid_nearmiss.txt', 'gru_hybrid_tomek.txt', 'gru_log_all.txt', 'gru_minmax_all.txt', 'gru_nonorm.txt', 'gru_tomek_nonsep_2000.txt', 'gru_tomek_nonsep_500.txt', 'gru_tomek_nonsep_8000.txt', 'gru_tomek_rus2000_smote2000.txt', 'gru_tomek_rus500_smote500.txt', 'gru_tomek_rus8000_smote8000.txt', 'gru_tomek_smote_balanced.txt', 'gru_zscore_all.txt', 'inceptiontime_hybrid.txt', 'inceptiontime_hybrid_enn.txt', 'inceptiontime_hybrid_nearmiss.txt', 'inceptiontime_hybrid_tomek.txt', 'inceptiontime_log_all.txt', 'inceptiontime_minmax_all.txt', 'inceptiontime_nonorm.txt', 'inceptiontime_tomek_nonsep_2000.txt', 'inceptiontime_tomek_nonsep_500.txt', 'inceptiontime_tomek_nonsep_8000.txt', 'inceptiontime_tomek_rus2000_smote2000.txt', 'inceptiontime_tomek_rus500_smote500.txt', 'inceptiontime_tomek_rus8000_smote8000.txt', 'inceptiontime_tomek_smote_balanced.txt', 'inceptiontime_zscore_all.txt', 'patchtst_hybrid.txt', 'patchtst_hybrid_enn.txt', 'patchtst_hybrid_nearmiss.txt', 'patchtst_hybrid_tomek.txt', 'patchtst_log_all.txt', 'patchtst_minmax_all.txt', 'patchtst_nonorm.txt', 'patchtst_tomek_nonsep_2000.txt', 'patchtst_tomek_nonsep_500.txt', 'patchtst_tomek_nonsep_8000.txt', 'patchtst_tomek_rus2000_smote2000.txt', 'patchtst_tomek_rus500_smote500.txt', 'patchtst_tomek_rus8000_smote8000.txt', 'patchtst_tomek_smote_balanced.txt', 'patchtst_zscore_all.txt', 'svm_hybrid.txt', 'svm_hybrid_enn.txt', 'svm_hybrid_nearmiss.txt', 'svm_hybrid_tomek.txt', 'svm_log_all.txt', 'svm_minmax_all.txt', 'svm_nonorm.txt', 'svm_tomek_nonsep_2000.txt', 'svm_tomek_nonsep_500.txt', 'svm_tomek_nonsep_8000.txt', 'svm_tomek_rus2000_smote2000.txt', 'svm_tomek_rus500_smote500.txt', 'svm_tomek_rus8000_smote8000.txt', 'svm_tomek_smote_balanced.txt', 'svm_zscore_all.txt']
